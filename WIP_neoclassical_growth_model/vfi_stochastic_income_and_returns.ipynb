# %%
# Value Function Iteration with IID Income
# Greg Kaplan 2017
# Translated by Tom Sweeney Dec 2020

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve 
from discrete_normal import discrete_normal
from itertools import chain
import pandas as pd

# %%
# PARAMETERS

## preferences
risk_aver = 2
beta = 0.959

## return risk: discretized N(mu,sigma^2)
mu_r = 0.03
sd_r = 0.01
nr = 5

## income risk: discretized N(mu,sigma^2)
mu_y = 1
sd_y = 0.2
ny = 5

## asset grids
na = 2000
amax = 1000
borrow_lim = 0
agrid_par = 1 # 1 for linear, 0 for L-shaped

## computation
max_iter = 2000
tol_iter = 1.0e-1
Nsim = 50000 #specify number of individuals in economy
Tsim = 1000 #specify number of time periods to simulate for

# %%
# OPTIONS
Display = 1
DoSimulate = 1
MakePlots = 1

# DRAW RANDOM NUMBERS
np.random.seed(2020)


# SET UP GRIDS

## assets
agrid = np.linspace(0,1,na).reshape(na,1)
agrid = agrid**(1/agrid_par)
agrid = borrow_lim + (amax-borrow_lim)*agrid

## income: disretize normal distribution
width_y = fsolve(lambda x: discrete_normal(ny,mu_y,sd_y,x)[0],2)
temp, ygrid, ydist = discrete_normal(ny,mu_y,sd_y,width_y)
ycumdist = np.cumsum(ydist)

## returns: disretize normal distribution
width_r = fsolve(lambda x: discrete_normal(nr,mu_r,sd_r,x)[0],2)
temp, rgrid, rdist = discrete_normal(nr,mu_r,sd_r,width_r)
rcumdist = np.cumsum(rdist)

# Set up Rgrid = 1+rgrid
Rgrid = 1+rgrid

# UTILITY FUNCTION
if risk_aver==1:
    u = lambda c: np.log(c)
else:
    u = lambda c: (c**(1-risk_aver)-1)/(1-risk_aver)

# %%
# INITIALIZE VALUE FUNCTION

Vguess = np.zeros((nr,na,ny))
for ir in range(0,nr):
    for iy in range(0,ny):
        Vguess[ir,:,iy] = u(rgrid[ir]*agrid[0]+ygrid[iy])/(1-beta)

# %%
# ITERATE ON VALUE FUNCTION

V_full=Vguess.copy()
sav_full = np.zeros((nr,na,ny))
savind_full = np.zeros((nr,na,ny), dtype=int)
con_full = np.zeros((nr,na,ny))


for ir in range(0,nr):

    V = Vguess[ir].copy()

    Vdiff = 1
    Iter = 0
    
    if Display >= 1:
        print('Return index: ' + str(ir), ' Return value: ' + str(Rgrid[ir]))

    while Iter <= max_iter and Vdiff > tol_iter:
        Iter = Iter + 1
        Vlast = V.copy()
        V = np.zeros((na,ny))
        sav = np.zeros((na,ny))
        savind = np.zeros((na,ny), dtype=int)
        con = np.zeros((na,ny))

        ## loop over assets
        for ia in range(0,na):

            ## loop over income
            for iy in range(0,ny):
                cash = Rgrid[ir]*agrid[ia] + ygrid[iy]
                Vchoice = u(np.maximum(cash-agrid,1.0e-10)) + beta*(Vlast @ ydist)           
                V[ia,iy] = np.max(Vchoice)
                savind[ia,iy] = np.argmax(Vchoice)
                sav[ia,iy] = agrid[savind[ia,iy]]
                con[ia,iy] = cash - sav[ia,iy]

        Vdiff = np.max(abs(V-Vlast))
        if Display >= 1:
            print('Iteration no. ' + str(Iter), ' max val fn diff is ' + str(Vdiff))

    V_full[ir] = V
    sav_full[ir] = sav
    savind_full[ir] = savind
    con_full[ir] = con
    
    if Display >= 1:
        print('Return index ' + str(ir), ' Finished.')
        print('-------------------------------------')
# Out:
# Return index: 0  Return value: [1.01066269]
# Iteration no. 1  max val fn diff is 15.338204500574085
# Iteration no. 2  max val fn diff is 0.9988802453291059
# Iteration no. 3  max val fn diff is 0.9560889657654816
# Iteration no. 4  max val fn diff is 0.9151229810779502
# Iteration no. 5  max val fn diff is 0.8759043830649902
# Iteration no. 6  max val fn diff is 0.838358617506159
# Iteration no. 7  max val fn diff is 0.8024143210637265
# Iteration no. 8  max val fn diff is 0.7680031438476291
# Iteration no. 9  max val fn diff is 0.7350598022154351
# Iteration no. 10  max val fn diff is 0.7035216007678589
# Iteration no. 11  max val fn diff is 0.6733286736145123
# Iteration no. 12  max val fn diff is 0.6444237540206785
# Iteration no. 13  max val fn diff is 0.616751786808102
# Iteration no. 14  max val fn diff is 0.5902604015226398
# Iteration no. 15  max val fn diff is 0.5648992783670437
# Iteration no. 16  max val fn diff is 0.5406200949296185
# Iteration no. 17  max val fn diff is 0.5173768868138762
# Iteration no. 18  max val fn diff is 0.4951257881840796
# Iteration no. 19  max val fn diff is 0.47382386701465684
# Iteration no. 20  max val fn diff is 0.45343163548226606
# Iteration no. 21  max val fn diff is 0.43390963393114923
# Iteration no. 22  max val fn diff is 0.41522077924279266
# Iteration no. 23  max val fn diff is 0.39733047136518174
# Iteration no. 24  max val fn diff is 0.38020357204216104
# Iteration no. 25  max val fn diff is 0.36380851376753576
# Iteration no. 26  max val fn diff is 0.34811344338997685
# Iteration no. 27  max val fn diff is 0.33308881113193856
# Iteration no. 28  max val fn diff is 0.3187069181804034
# Iteration no. 29  max val fn diff is 0.3049384990844892
# Iteration no. 30  max val fn diff is 0.2917596297014917
# Iteration no. 31  max val fn diff is 0.279143826994261
# Iteration no. 32  max val fn diff is 0.2670673796547085
# Iteration no. 33  max val fn diff is 0.2555081035211373
# Iteration no. 34  max val fn diff is 0.24444257794745283
# Iteration no. 35  max val fn diff is 0.23385028085955994
# Iteration no. 36  max val fn diff is 0.2237128141107192
# Iteration no. 37  max val fn diff is 0.2140077467633752
# Iteration no. 38  max val fn diff is 0.20471883498074916
# Iteration no. 39  max val fn diff is 0.19582876967977825
# Iteration no. 40  max val fn diff is 0.18731853209069627
# Iteration no. 41  max val fn diff is 0.17917323904663363
# Iteration no. 42  max val fn diff is 0.1713772734307426
# Iteration no. 43  max val fn diff is 0.16391554220981064
# Iteration no. 44  max val fn diff is 0.15677419521021818
# Iteration no. 45  max val fn diff is 0.14993939196589068
# Iteration no. 46  max val fn diff is 0.143397248412505
# Iteration no. 47  max val fn diff is 0.1371363411241191
# Iteration no. 48  max val fn diff is 0.13114586228344294
# Iteration no. 49  max val fn diff is 0.12541155199043885
# Iteration no. 50  max val fn diff is 0.11992279543367346
# Iteration no. 51  max val fn diff is 0.11467212133097604
# Iteration no. 52  max val fn diff is 0.10964744709380625
# Iteration no. 53  max val fn diff is 0.10483621551668776
# Iteration no. 54  max val fn diff is 0.10023569490193651
# Iteration no. 55  max val fn diff is 0.09583094250390545
# Return index 0  Finished.
# -------------------------------------
# Return index: 1  Return value: [1.02033135]
# Iteration no. 1  max val fn diff is 15.338213865279394
# Iteration no. 2  max val fn diff is 0.9989250677844804
# Iteration no. 3  max val fn diff is 0.9561917362167168
# Iteration no. 4  max val fn diff is 0.9153028702245991
# Iteration no. 5  max val fn diff is 0.8761775916416017
# Iteration no. 6  max val fn diff is 0.8387386546356197
# Iteration no. 7  max val fn diff is 0.8029122943703237
# Iteration no. 8  max val fn diff is 0.7686280010924369
# Iteration no. 9  max val fn diff is 0.7358184583665093
# Iteration no. 10  max val fn diff is 0.7044194259964724
# Iteration no. 11  max val fn diff is 0.6743693544810556
# Iteration no. 12  max val fn diff is 0.6456095727696045
# Iteration no. 13  max val fn diff is 0.6180838967484608
# Iteration no. 14  max val fn diff is 0.5917389567290705
# Iteration no. 15  max val fn diff is 0.5665232489540379
# Iteration no. 16  max val fn diff is 0.5423878759238274
# Iteration no. 17  max val fn diff is 0.5192860379754975
# Iteration no. 18  max val fn diff is 0.49717291650599016
# Iteration no. 19  max val fn diff is 0.47600612174456813
# Iteration no. 20  max val fn diff is 0.45574418813147055
# Iteration no. 21  max val fn diff is 0.4363486220329076
# Iteration no. 22  max val fn diff is 0.4177813940312127
# Iteration no. 23  max val fn diff is 0.4000073775486772
# Iteration no. 24  max val fn diff is 0.3829916183821567
# Iteration no. 25  max val fn diff is 0.36670296442116346
# Iteration no. 26  max val fn diff is 0.35110826294400077
# Iteration no. 27  max val fn diff is 0.33617913507798747
# Iteration no. 28  max val fn diff is 0.32188610855034305
# Iteration no. 29  max val fn diff is 0.3082022878720281
# Iteration no. 30  max val fn diff is 0.29510113648462166
# Iteration no. 31  max val fn diff is 0.28255827011689405
# Iteration no. 32  max val fn diff is 0.27054939412886014
# Iteration no. 33  max val fn diff is 0.25905137391446686
# Iteration no. 34  max val fn diff is 0.24804226300489063
# Iteration no. 35  max val fn diff is 0.2375030514276304
# Iteration no. 36  max val fn diff is 0.22740991373460062
# Iteration no. 37  max val fn diff is 0.21774795085334375
# Iteration no. 38  max val fn diff is 0.20849546262456897
# Iteration no. 39  max val fn diff is 0.19963606504454035
# Iteration no. 40  max val fn diff is 0.19115381014695032
# Iteration no. 41  max val fn diff is 0.18303162732166456
# Iteration no. 42  max val fn diff is 0.17525456729212863
# Iteration no. 43  max val fn diff is 0.16780786712373086
# Iteration no. 44  max val fn diff is 0.16067735723077803
# Iteration no. 45  max val fn diff is 0.1538490881108423
# Iteration no. 46  max val fn diff is 0.14731093110187388
# Iteration no. 47  max val fn diff is 0.141050880973296
# Iteration no. 48  max val fn diff is 0.13505460744934084
# Iteration no. 49  max val fn diff is 0.12931571066825143
# Iteration no. 50  max val fn diff is 0.12381817617390922
# Iteration no. 51  max val fn diff is 0.11855341824159282
# Iteration no. 52  max val fn diff is 0.11351444281006096
# Iteration no. 53  max val fn diff is 0.10868693397083007
# Iteration no. 54  max val fn diff is 0.10406491321393219
# Iteration no. 55  max val fn diff is 0.09963963328262793
# Return index 1  Finished.
# -------------------------------------
# Return index: 2  Return value: [1.03]
# Iteration no. 1  max val fn diff is 15.338223054275561
# Iteration no. 2  max val fn diff is 0.9989687624320718
# Iteration no. 3  max val fn diff is 0.9562912136189046
# Iteration no. 4  max val fn diff is 0.9154757685133152
# Iteration no. 5  max val fn diff is 0.8764383214721816
# Iteration no. 6  max val fn diff is 0.8390987839725055
# Iteration no. 7  max val fn diff is 0.8033808602483345
# Iteration no. 8  max val fn diff is 0.7692118668927179
# Iteration no. 9  max val fn diff is 0.7365225233215087
# Iteration no. 10  max val fn diff is 0.7052468447601914
# Iteration no. 11  max val fn diff is 0.675321850475842
# Iteration no. 12  max val fn diff is 0.6466875755201489
# Iteration no. 13  max val fn diff is 0.6192868775344476
# Iteration no. 14  max val fn diff is 0.5930650609827293
# Iteration no. 15  max val fn diff is 0.5679700529960883
# Iteration no. 16  max val fn diff is 0.5439524729691048
# Iteration no. 17  max val fn diff is 0.5209646797518825
# Iteration no. 18  max val fn diff is 0.49896147875431573
# Iteration no. 19  max val fn diff is 0.4778998408588677
# Iteration no. 20  max val fn diff is 0.4577385052519922
# Iteration no. 21  max val fn diff is 0.43843805154860505
# Iteration no. 22  max val fn diff is 0.41996128952913914
# Iteration no. 23  max val fn diff is 0.402271813857352
# Iteration no. 24  max val fn diff is 0.385336114602147
# Iteration no. 25  max val fn diff is 0.36912065254025705
# Iteration no. 26  max val fn diff is 0.3535949433591199
# Iteration no. 27  max val fn diff is 0.33872857759683583
# Iteration no. 28  max val fn diff is 0.32449329995567844
# Iteration no. 29  max val fn diff is 0.310861824353978
# Iteration no. 30  max val fn diff is 0.2978085406994495
# Iteration no. 31  max val fn diff is 0.2853077889122808
# Iteration no. 32  max val fn diff is 0.2733361033373747
# Iteration no. 33  max val fn diff is 0.26187143161677184
# Iteration no. 34  max val fn diff is 0.25089069464763725
# Iteration no. 35  max val fn diff is 0.24037410648420732
# Iteration no. 36  max val fn diff is 0.2303014857208261
# Iteration no. 37  max val fn diff is 0.2206543926095641
# Iteration no. 38  max val fn diff is 0.21141331440794175
# Iteration no. 39  max val fn diff is 0.20256215783556897
# Iteration no. 40  max val fn diff is 0.19408407375863845
# Iteration no. 41  max val fn diff is 0.1859629862682084
# Iteration no. 42  max val fn diff is 0.17818345530509205
# Iteration no. 43  max val fn diff is 0.1707314472427761
# Iteration no. 44  max val fn diff is 0.16359281475191878
# Iteration no. 45  max val fn diff is 0.15675394436924606
# Iteration no. 46  max val fn diff is 0.15020224241098745
# Iteration no. 47  max val fn diff is 0.14392589284600632
# Iteration no. 48  max val fn diff is 0.13791296778478923
# Iteration no. 49  max val fn diff is 0.1321527208032549
# Iteration no. 50  max val fn diff is 0.12663323208257538
# Iteration no. 51  max val fn diff is 0.12134592167940994
# Iteration no. 52  max val fn diff is 0.1162803520909037
# Iteration no. 53  max val fn diff is 0.11142601798436047
# Iteration no. 54  max val fn diff is 0.10677677560649101
# Iteration no. 55  max val fn diff is 0.10231989493819071
# Iteration no. 56  max val fn diff is 0.09805204466274375
# Return index 2  Finished.
# -------------------------------------
# Return index: 3  Return value: [1.03966865]
# Iteration no. 1  max val fn diff is 15.338232072461848
# Iteration no. 2  max val fn diff is 0.9990113683848159
# Iteration no. 3  max val fn diff is 0.9563875378570345
# Iteration no. 4  max val fn diff is 0.9156420027019407
# Iteration no. 5  max val fn diff is 0.8766872545420679
# Iteration no. 6  max val fn diff is 0.8394402181817129
# Iteration no. 7  max val fn diff is 0.8038220463708745
# Iteration no. 8  max val fn diff is 0.7697578116372377
# Iteration no. 9  max val fn diff is 0.7371763544096188
# Iteration no. 10  max val fn diff is 0.706009997024073
# Iteration no. 11  max val fn diff is 0.6761944862263194
# Iteration no. 12  max val fn diff is 0.6476686310666047
# Iteration no. 13  max val fn diff is 0.6203741298563195
# Iteration no. 14  max val fn diff is 0.594255792002043
# Iteration no. 15  max val fn diff is 0.5692608569071549
# Iteration no. 16  max val fn diff is 0.5453389929130452
# Iteration no. 17  max val fn diff is 0.5224424378548793
# Iteration no. 18  max val fn diff is 0.500525927738348
# Iteration no. 19  max val fn diff is 0.47954561935028295
# Iteration no. 20  max val fn diff is 0.45946058973721904
# Iteration no. 21  max val fn diff is 0.44023128830385794
# Iteration no. 22  max val fn diff is 0.4218198220495566
# Iteration no. 23  max val fn diff is 0.40419075109642577
# Iteration no. 24  max val fn diff is 0.38730947936941007
# Iteration no. 25  max val fn diff is 0.3711440062551983
# Iteration no. 26  max val fn diff is 0.3556625300110188
# Iteration no. 27  max val fn diff is 0.34083595636983866
# Iteration no. 28  max val fn diff is 0.326634933593521
# Iteration no. 29  max val fn diff is 0.31303381617032855
# Iteration no. 30  max val fn diff is 0.3000053657063617
# Iteration no. 31  max val fn diff is 0.2875255760720563
# Iteration no. 32  max val fn diff is 0.27557071813604495
# Iteration no. 33  max val fn diff is 0.264118720916553
# Iteration no. 34  max val fn diff is 0.2531471909904006
# Iteration no. 35  max val fn diff is 0.24263575492330958
# Iteration no. 36  max val fn diff is 0.23256544199948337
# Iteration no. 37  max val fn diff is 0.22291709133516235
# Iteration no. 38  max val fn diff is 0.2136718921873424
# Iteration no. 39  max val fn diff is 0.20481380560125118
# Iteration no. 40  max val fn diff is 0.1963258569594295
# Iteration no. 41  max val fn diff is 0.18819263999673908
# Iteration no. 42  max val fn diff is 0.18039883501513643
# Iteration no. 43  max val fn diff is 0.17293030066438675
# Iteration no. 44  max val fn diff is 0.16577279321606753
# Iteration no. 45  max val fn diff is 0.1589135959303256
# Iteration no. 46  max val fn diff is 0.1523399695841121
# Iteration no. 47  max val fn diff is 0.1460407052858912
# Iteration no. 48  max val fn diff is 0.1400030006540831
# Iteration no. 49  max val fn diff is 0.1342155722010716
# Iteration no. 50  max val fn diff is 0.12867044285086493
# Iteration no. 51  max val fn diff is 0.12335385853437586
# Iteration no. 52  max val fn diff is 0.11825938096763622
# Iteration no. 53  max val fn diff is 0.11337570075214742
# Iteration no. 54  max val fn diff is 0.10869475729316491
# Iteration no. 55  max val fn diff is 0.104207924635638
# Iteration no. 56  max val fn diff is 0.09990736039119597
# Return index 3  Finished.
# -------------------------------------
# Return index: 4  Return value: [1.04933731]
# Iteration no. 1  max val fn diff is 15.33824092455705
# Iteration no. 2  max val fn diff is 0.9990529223955106
# Iteration no. 3  max val fn diff is 0.9564808345291297
# Iteration no. 4  max val fn diff is 0.9158018994264583
# Iteration no. 5  max val fn diff is 0.8769250331632605
# Iteration no. 6  max val fn diff is 0.8397641119779671
# Iteration no. 7  max val fn diff is 0.8042376856482489
# Iteration no. 8  max val fn diff is 0.7702686606546205
# Iteration no. 9  max val fn diff is 0.7377839952100835
# Iteration no. 10  max val fn diff is 0.7067145148417415
# Iteration no. 11  max val fn diff is 0.6769946815326842
# Iteration no. 12  max val fn diff is 0.6485621749467843
# Iteration no. 13  max val fn diff is 0.6213580656405586
# Iteration no. 14  max val fn diff is 0.5953262261508421
# Iteration no. 15  max val fn diff is 0.570413458374988
# Iteration no. 16  max val fn diff is 0.5465691808148598
# Iteration no. 17  max val fn diff is 0.5237454233995607
# Iteration no. 18  max val fn diff is 0.5018962109222223
# Iteration no. 19  max val fn diff is 0.4809781960888895
# Iteration no. 20  max val fn diff is 0.4609499777359858
# Iteration no. 21  max val fn diff is 0.4417720480679801
# Iteration no. 22  max val fn diff is 0.42340707108625075
# Iteration no. 23  max val fn diff is 0.40581933031461936
# Iteration no. 24  max val fn diff is 0.38897428003381584
# Iteration no. 25  max val fn diff is 0.3728400407760706
# Iteration no. 26  max val fn diff is 0.35738513482502654
# Iteration no. 27  max val fn diff is 0.34258076003573734
# Iteration no. 28  max val fn diff is 0.3283976183657824
# Iteration no. 29  max val fn diff is 0.31481021293985734
# Iteration no. 30  max val fn diff is 0.3017917410384783
# Iteration no. 31  max val fn diff is 0.28931816869997107
# Iteration no. 32  max val fn diff is 0.2773661966605907
# Iteration no. 33  max val fn diff is 0.26591379019619055
# Iteration no. 34  max val fn diff is 0.2549384861588493
# Iteration no. 35  max val fn diff is 0.24442154623795176
# Iteration no. 36  max val fn diff is 0.23434178944409112
# Iteration no. 37  max val fn diff is 0.2246820548137265
# Iteration no. 38  max val fn diff is 0.21542391783784964
# Iteration no. 39  max val fn diff is 0.20655021715299782
# Iteration no. 40  max val fn diff is 0.19804496107656533
# Iteration no. 41  max val fn diff is 0.18989249533053254
# Iteration no. 42  max val fn diff is 0.1820781209968132
# Iteration no. 43  max val fn diff is 0.1745872832408324
# Iteration no. 44  max val fn diff is 0.1674070735448474
# Iteration no. 45  max val fn diff is 0.16052373976678425
# Iteration no. 46  max val fn diff is 0.1539249019012452
# Iteration no. 47  max val fn diff is 0.14759872116383832
# Iteration no. 48  max val fn diff is 0.14153484435385977
# Iteration no. 49  max val fn diff is 0.13572020329781154
# Iteration no. 50  max val fn diff is 0.13014623338312958
# Iteration no. 51  max val fn diff is 0.12480207229478069
# Iteration no. 52  max val fn diff is 0.11967821475456475
# Iteration no. 53  max val fn diff is 0.11476582332595342
# Iteration no. 54  max val fn diff is 0.11005566656607613
# Iteration no. 55  max val fn diff is 0.10553943300173074
# Iteration no. 56  max val fn diff is 0.10120972747577284
# Iteration no. 57  max val fn diff is 0.09705729439391675
# Return index 4  Finished.
# -------------------------------------

# %%
## Assume return risk is systemic. Create array of size (1*Tsim) realized returns at period t

# 'rdist' is the probability of each realization
##Turn rdist values into a list------##
rlist = rdist.tolist()

r_probabilities = []
for sublist in rlist:
    for x in sublist:
        r_probabilities.append(x)
##-----------------------------------##

rindsim = np.zeros((1,Tsim),dtype=int)
for t in range(0,Tsim):
    rindsim[0][t]=np.random.choice([0,1,2,3,4], p=r_probabilities) #randomly choose index of economy returns

## Check that returns over time periods is normally distributed
import seaborn as sns    
sns.distplot(pd.DataFrame(rindsim.transpose()),kde=False)
# Out:
# <AxesSubplot:>

# %%
# SIMULATE
if DoSimulate == 1:
    
    ## Create a matrix of size (Nsim * Tsim) of income realizations for Nsim individuals over Tsim periods
    yrand = np.random.rand(Nsim,Tsim) # draw random realizations from U~[0,1)
    
    ## Create matrices of size (Nsim * Tsim)
    yindsim = np.zeros((Nsim,Tsim), dtype=int) #this is a matrix of every individuals' income at period t
    aindsim = np.zeros((Nsim,Tsim), dtype=int) #this is a matrix of every individuals' assets at period t
    
    ## initial assets
    aindsim[:,0] = 0 #selecting a vector of size (Nsim * 1); this command sets the first period assets to 0 for every individual
    
    
    ##-------------------------------------------------------------------------------------------##
    ##This part is all to set randomized income realizations according to the discretized normal realizations we defined earlier
    
    ## loop over time periods
    for it in range(0,Tsim):
        if Display >= 1 and (it+1)%100 == 0:
            print(' Simulating, time period ' + str(it+1))

        #this below operation sets the 'minimum' income realizations of yindsim to 0
        """Code explanation:
            (1) yrand[:,it] selects vector of size (Nsim*1) individuals' income at period t that we are iterating on
            (2) check if yrand[:,it] is weakly smaller than the minimum value of ycumdist
            (3) select all rows of the vector 'yindsim at time t' that are less than the minimum of (2), and sets all these rows to 0
        """        
        yindsim[yrand[:,it]<=ycumdist[0],it] = 0 
            
        #following a similar logic, we set the randomized income realizations to the discretized normal income realization values
        #Now, the yindsim vector at time t only has income values that are in ycumdist            
        for iy in range(1,ny):
            yindsim[np.logical_and(yrand[:,it]>ycumdist[iy-1], yrand[:,it]<=ycumdist[iy]),it] = iy

        ##-------------------------------------------------------------------------------------------##


        """--Now we can simulate the path of assets--"""        

        ## asset choice
        """Code explanation:
            (1) yrand[:,it] selects vector of size (Nsim*1) individuals' income at period t that we are iterating on
            (2) Select only the rows where yindsim[:,it]==iy. We loop over every iy in ny, so every row will be selected at some point
            (3) Individuals will choose optimal assets of period t+1 according to their savings policy function given economy interest rate
        """
        if it < Tsim-1:
            for iy in range(0,ny):
                aindsim[yindsim[:,it]==iy,it+1] = savind_full[rindsim[0][it],aindsim[yindsim[:,it]==iy,it],iy]

    ## assign actual asset and income values
    asim = agrid[aindsim]
    ysim = ygrid[yindsim]
# Out:
#  Simulating, time period 100
#  Simulating, time period 200
#  Simulating, time period 300
#  Simulating, time period 400
#  Simulating, time period 500
#  Simulating, time period 600
#  Simulating, time period 700
#  Simulating, time period 800
#  Simulating, time period 900
#  Simulating, time period 1000

# %%
# MAKE PLOTS
if MakePlots==1:
    
    ## consumption policy function
    plt.plot(agrid,con[:,0],'b-',label = 'Lowest income state')
    plt.plot(agrid,con[:,ny-1],'r-', label = 'Highest income state')
    plt.grid()
    plt.xlim((0,amax))
    ### plt.title('Consumption Policy Function')
    plt.title('Consumption')
    plt.legend()
    plt.show()

    ## savings policy function
    plt.plot(agrid,sav[:,0]-agrid[:,0],'b-')
    plt.plot(agrid,sav[:,ny-1]-agrid[:,0],'r-')
    plt.plot(agrid,np.zeros((na,1)),'k',linewidth=0.5)
    plt.grid()
    plt.xlim((0,amax))
    ### plt.title('Savings Policy Function (a''-a)')
    plt.title('Savings')
    plt.show()
    
    ## nice zoom
    xlimits = (0,1)
    xlimind = np.ones(na, dtype=bool)
    if np.min(agrid) < xlimits[0]:
        xlimind = np.logical_and(xlimind,(agrid[:,0]>=np.max(agrid[agrid<xlimits[0]])))
    elif np.min(agrid) > xlimits[1]:
        xlimind = 0
    if np.max(agrid) > xlimits[1]:
        xlimind = np.logical_and(xlimind,(agrid[:,0]<=np.min(agrid[agrid>xlimits[1]])))
    elif np.max(agrid) < xlimits[0]:
        xlimind = 0

    ## consumption policy function: zoomed in
    plt.plot(agrid[xlimind],con[xlimind,0],'b-o',linewidth=2)
    plt.plot(agrid[xlimind],con[xlimind,ny-1],'r-o',linewidth=2)
    plt.grid()
    plt.xlim(xlimits)
    plt.title('Consumption: Zoomed')
    plt.show()

    ## savings policy function: zoomed in
    plt.plot(agrid[xlimind],sav[xlimind,0]-agrid[xlimind,0],'b-o',linewidth=2)
    plt.plot(agrid[xlimind],sav[xlimind,ny-1]-agrid[xlimind,0],'r-o',linewidth=2)
    plt.plot(agrid,np.zeros((na,1)),'k',linewidth =0.5)
    plt.grid()
    plt.xlim(xlimits)
    plt.title('Savings: Zoomed (a\'-a)')
    plt.show()

    ## income distribution
    plt.hist(ysim[:,Tsim-1],len(ygrid),facecolor=(0,0.5,0.5),edgecolor='blue')
    plt.ylabel('')
    plt.title('Income distribution')
    plt.show()

    ## asset distribution
    plt.hist(asim[:,Tsim-1],40,facecolor=(.7,.7,.7),edgecolor='black')
    plt.ylabel('')
    plt.title('Asset distribution')
    plt.show()

    ## convergence check
    plt.plot(range(0,Tsim),np.mean(asim,0),'k-',linewidth=1.5)
    plt.xlabel('Time Period')
    plt.title('Mean Asset Convergence')
    plt.show()

    ## asset distribution statistics
    aysim = asim[:,Tsim-1]/np.mean(ysim[:,Tsim-1])
    print('Mean assets: ' + str(np.mean(aysim)))
    print('Fraction borrowing constrained: ' + str(np.sum(aysim==borrow_lim)/Nsim * 100) + '%')
    print('10th Percentile: ' + str(np.quantile(aysim,.1)))
    print('50th Percentile: ' + str(np.quantile(aysim,.5)))
    print('90th Percentile: ' + str(np.quantile(aysim,.9)))
    print('99th Percentile: ' + str(np.quantile(aysim,.99)))
# Out:
# Mean assets: 0.584643245960947
# Fraction borrowing constrained: 27.107999999999997%
# 10th Percentile: 0.0
# 50th Percentile: 0.4992171988873445
# 90th Percentile: 1.4976515966620336
# 99th Percentile: 1.996868795549378
