# %%
# Value Function Iteration with IID Income
# Greg Kaplan 2017
# Translated by Tom Sweeney Dec 2020

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve 
from discrete_normal import discrete_normal

# PARAMETERS

## preferences
risk_aver = 2
beta = 0.9688

## returns
r = 0.03
R = 1+r

## income risk: discretized N(mu,sigma^2)
mu_y = 1
sd_y = 0.2
ny = 5

## asset grids
na = 2000
amax = 900
borrow_lim = 0
agrid_par = 1 # 1 for linear, 0 for L-shaped

## computation
max_iter = 1000
tol_iter = 1.0e-4
Nsim = 50000
Tsim = 2500

# OPTIONS
Display = 1
DoSimulate = 1
MakePlots = 1

# DRAW RANDOM NUMBERS

np.random.seed(2020)
yrand = np.random.rand(Nsim,Tsim)

# SET UP GRIDS

## assets
agrid = np.linspace(0,1,na).reshape(na,1)
agrid = agrid**(1/agrid_par)
agrid = borrow_lim + (amax-borrow_lim)*agrid

## income: disretize normal distribution
width = fsolve(lambda x: discrete_normal(ny,mu_y,sd_y,x)[0],2)
temp, ygrid, ydist = discrete_normal(ny,mu_y,sd_y,width)
ycumdist = np.cumsum(ydist)

# UTILITY FUNCTION

if risk_aver==1:
    u = lambda c: np.log(c)
else:
    u = lambda c: (c**(1-risk_aver)-1)/(1-risk_aver) 

# INITIALIZE VALUE FUNCTION

Vguess = np.zeros((na,ny))
for iy in range(0,ny):
    Vguess[:,iy] = u(r*agrid[0]+ygrid[iy])/(1-beta)

### Vguess = np.ones((na,ny))

# ITERATE ON VALUE FUNCTION

V = Vguess.copy()

Vdiff = 1
Iter = 0

# %%
while Iter <= max_iter and Vdiff > tol_iter:
    Iter = Iter + 1
    Vlast = V.copy()
    V = np.zeros((na,ny))
    sav = np.zeros((na,ny))
    savind = np.zeros((na,ny), dtype=int)
    con = np.zeros((na,ny))
    
    ## loop over assets
    for ia in range(0,na):
        
        ## loop over income
        for iy in range(0,ny):
            cash = R*agrid[ia] + ygrid[iy]
            Vchoice = u(np.maximum(cash-agrid,1.0e-10)) + beta*(Vlast @ ydist)           
            V[ia,iy] = np.max(Vchoice)
            savind[ia,iy] = np.argmax(Vchoice)
            sav[ia,iy] = agrid[savind[ia,iy]]
            con[ia,iy] = cash - sav[ia,iy]
    
    Vdiff = np.max(abs(V-Vlast))
    if Display >= 1:
        print('Iteration no. ' + str(Iter), ' max val fn diff is ' + str(Vdiff))
# Out:
# Iteration no. 1  max val fn diff is 19.82809432276025
# Iteration no. 2  max val fn diff is 1.008877771624777
# Iteration no. 3  max val fn diff is 0.9754722226854502
# Iteration no. 4  max val fn diff is 0.9432269431556701
# Iteration no. 5  max val fn diff is 0.9120982935068991
# Iteration no. 6  max val fn diff is 0.8820444823577325
# Iteration no. 7  max val fn diff is 0.8530254855216413
# Iteration no. 8  max val fn diff is 0.8250029230092668
# Iteration no. 9  max val fn diff is 0.797940012202667
# Iteration no. 10  max val fn diff is 0.7718014938025624
# Iteration no. 11  max val fn diff is 0.7465535704090502
# Iteration no. 12  max val fn diff is 0.7221638183944421
# Iteration no. 13  max val fn diff is 0.6986009619178581
# Iteration no. 14  max val fn diff is 0.6758353037860871
# Iteration no. 15  max val fn diff is 0.6538380779986319
# Iteration no. 16  max val fn diff is 0.6325815246310551
# Iteration no. 17  max val fn diff is 0.6120396527424461
# Iteration no. 18  max val fn diff is 0.5921865271450297
# Iteration no. 19  max val fn diff is 0.5729979948580883
# Iteration no. 20  max val fn diff is 0.554450414302595
# Iteration no. 21  max val fn diff is 0.5365213503035484
# Iteration no. 22  max val fn diff is 0.519188959900708
# Iteration no. 23  max val fn diff is 0.5024324612863662
# Iteration no. 24  max val fn diff is 0.4862313244897667
# Iteration no. 25  max val fn diff is 0.4705673139346871
# Iteration no. 26  max val fn diff is 0.4554205163744989
# Iteration no. 27  max val fn diff is 0.4407737332015351
# Iteration no. 28  max val fn diff is 0.4266097784903664
# Iteration no. 29  max val fn diff is 0.41291155091576925
# Iteration no. 30  max val fn diff is 0.39966311325136417
# Iteration no. 31  max val fn diff is 0.3868499199292508
# Iteration no. 32  max val fn diff is 0.37445657209893923
# Iteration no. 33  max val fn diff is 0.36246846514659836
# Iteration no. 34  max val fn diff is 0.3508716194957664
# Iteration no. 35  max val fn diff is 0.3396534817644685
# Iteration no. 36  max val fn diff is 0.32880164980153026
# Iteration no. 37  max val fn diff is 0.318302414193969
# Iteration no. 38  max val fn diff is 0.30814421100161127
# Iteration no. 39  max val fn diff is 0.2983170597617466
# Iteration no. 40  max val fn diff is 0.2888083293473329
# Iteration no. 41  max val fn diff is 0.2796074536429778
# Iteration no. 42  max val fn diff is 0.2707046980604595
# Iteration no. 43  max val fn diff is 0.2620898326578178
# Iteration no. 44  max val fn diff is 0.2537534476088581
# Iteration no. 45  max val fn diff is 0.24568592217047325
# Iteration no. 46  max val fn diff is 0.23787837128393363
# Iteration no. 47  max val fn diff is 0.2303237047138751
# Iteration no. 48  max val fn diff is 0.22301169627624162
# Iteration no. 49  max val fn diff is 0.2159341281725311
# Iteration no. 50  max val fn diff is 0.209083714143933
# Iteration no. 51  max val fn diff is 0.20245604526301975
# Iteration no. 52  max val fn diff is 0.19603785182779276
# Iteration no. 53  max val fn diff is 0.18982732893147514
# Iteration no. 54  max val fn diff is 0.18381602384019402
# Iteration no. 55  max val fn diff is 0.17799441864613286
# Iteration no. 56  max val fn diff is 0.17236404974900665
# Iteration no. 57  max val fn diff is 0.16690866451680364
# Iteration no. 58  max val fn diff is 0.16163177116407113
# Iteration no. 59  max val fn diff is 0.15651968954310647
# Iteration no. 60  max val fn diff is 0.1515750545740957
# Iteration no. 61  max val fn diff is 0.14678379678849396
# Iteration no. 62  max val fn diff is 0.14214751652847468
# Iteration no. 63  max val fn diff is 0.13765982912730834
# Iteration no. 64  max val fn diff is 0.13331227146679225
# Iteration no. 65  max val fn diff is 0.1291066050138454
# Iteration no. 66  max val fn diff is 0.1250317912633392
# Iteration no. 67  max val fn diff is 0.12108696526989249
# Iteration no. 68  max val fn diff is 0.11727069072583163
# Iteration no. 69  max val fn diff is 0.11357184873762449
# Iteration no. 70  max val fn diff is 0.10999080411192352
# Iteration no. 71  max val fn diff is 0.10652552319430342
# Iteration no. 72  max val fn diff is 0.10316982512376072
# Iteration no. 73  max val fn diff is 0.09991898336562599
# Iteration no. 74  max val fn diff is 0.09677106152397741
# Iteration no. 75  max val fn diff is 0.09372551536923268
# Iteration no. 76  max val fn diff is 0.09077445140459872
# Iteration no. 77  max val fn diff is 0.08791694656263971
# Iteration no. 78  max val fn diff is 0.08514973371214651
# Iteration no. 79  max val fn diff is 0.08247058781399375
# Iteration no. 80  max val fn diff is 0.079877275721568
# Iteration no. 81  max val fn diff is 0.0773639515620701
# Iteration no. 82  max val fn diff is 0.07493060698763898
# Iteration no. 83  max val fn diff is 0.07257427380236336
# Iteration no. 84  max val fn diff is 0.07029195019299195
# Iteration no. 85  max val fn diff is 0.0680844371227991
# Iteration no. 86  max val fn diff is 0.06594411737025752
# Iteration no. 87  max val fn diff is 0.06387114412170547
# Iteration no. 88  max val fn diff is 0.06186387153481476
# Iteration no. 89  max val fn diff is 0.05992009596334924
# Iteration no. 90  max val fn diff is 0.05803745999092769
# Iteration no. 91  max val fn diff is 0.056215098960635146
# Iteration no. 92  max val fn diff is 0.05445060142859148
# Iteration no. 93  max val fn diff is 0.052740410890454115
# Iteration no. 94  max val fn diff is 0.05108400363154786
# Iteration no. 95  max val fn diff is 0.049480015765958285
# Iteration no. 96  max val fn diff is 0.047926767014995875
# Iteration no. 97  max val fn diff is 0.04642218407385812
# Iteration no. 98  max val fn diff is 0.044964806412433944
# Iteration no. 99  max val fn diff is 0.043553573275119106
# Iteration no. 100  max val fn diff is 0.0421881073261936
# Iteration no. 101  max val fn diff is 0.040864492254460316
# Iteration no. 102  max val fn diff is 0.039582186267789865
# Iteration no. 103  max val fn diff is 0.03834023992664726
# Iteration no. 104  max val fn diff is 0.03713752163496764
# Iteration no. 105  max val fn diff is 0.035972616658774825
# Iteration no. 106  max val fn diff is 0.03484434383318202
# Iteration no. 107  max val fn diff is 0.03375143870187003
# Iteration no. 108  max val fn diff is 0.03269284377114445
# Iteration no. 109  max val fn diff is 0.03166749960440285
# Iteration no. 110  max val fn diff is 0.030674389309389483
# Iteration no. 111  max val fn diff is 0.029712756114740557
# Iteration no. 112  max val fn diff is 0.0287820132775245
# Iteration no. 113  max val fn diff is 0.027879989300380714
# Iteration no. 114  max val fn diff is 0.027006009088598404
# Iteration no. 115  max val fn diff is 0.02615941829321855
# Iteration no. 116  max val fn diff is 0.025339380697541714
# Iteration no. 117  max val fn diff is 0.024545186068433367
# Iteration no. 118  max val fn diff is 0.0237759136576976
# Iteration no. 119  max val fn diff is 0.0230306765168109
# Iteration no. 120  max val fn diff is 0.022308982279472644
# Iteration no. 121  max val fn diff is 0.02160994866032695
# Iteration no. 122  max val fn diff is 0.020932822925828987
# Iteration no. 123  max val fn diff is 0.02027694193613172
# Iteration no. 124  max val fn diff is 0.019641613209802955
# Iteration no. 125  max val fn diff is 0.01902621793465542
# Iteration no. 126  max val fn diff is 0.018430091305209118
# Iteration no. 127  max val fn diff is 0.017852618942352905
# Iteration no. 128  max val fn diff is 0.017293219028250206
# Iteration no. 129  max val fn diff is 0.016751605158834337
# Iteration no. 130  max val fn diff is 0.01622695225579207
# Iteration no. 131  max val fn diff is 0.015718730474482356
# Iteration no. 132  max val fn diff is 0.015226659336963877
# Iteration no. 133  max val fn diff is 0.014750087871448159
# Iteration no. 134  max val fn diff is 0.014288141047135383
# Iteration no. 135  max val fn diff is 0.013840674981132395
# Iteration no. 136  max val fn diff is 0.0134072167549526
# Iteration no. 137  max val fn diff is 0.012987326871485294
# Iteration no. 138  max val fn diff is 0.012580579986234852
# Iteration no. 139  max val fn diff is 0.012186565086910406
# Iteration no. 140  max val fn diff is 0.011804887634038863
# Iteration no. 141  max val fn diff is 0.01143521358473265
# Iteration no. 142  max val fn diff is 0.011077185258571376
# Iteration no. 143  max val fn diff is 0.010730352946563215
# Iteration no. 144  max val fn diff is 0.010394381871989822
# Iteration no. 145  max val fn diff is 0.010068918811661831
# Iteration no. 146  max val fn diff is 0.00975363893034853
# Iteration no. 147  max val fn diff is 0.009448229953221698
# Iteration no. 148  max val fn diff is 0.009152439493874454
# Iteration no. 149  max val fn diff is 0.008865962175324427
# Iteration no. 150  max val fn diff is 0.008588454384398148
# Iteration no. 151  max val fn diff is 0.008319617345335928
# Iteration no. 152  max val fn diff is 0.008059186415540154
# Iteration no. 153  max val fn diff is 0.007806904206280052
# Iteration no. 154  max val fn diff is 0.007562524488935907
# Iteration no. 155  max val fn diff is 0.007325800895841894
# Iteration no. 156  max val fn diff is 0.007096480678029593
# Iteration no. 157  max val fn diff is 0.0068743322642959015
# Iteration no. 158  max val fn diff is 0.006659133926731897
# Iteration no. 159  max val fn diff is 0.006450672542275271
# Iteration no. 160  max val fn diff is 0.006248737079268096
# Iteration no. 161  max val fn diff is 0.006053120638110698
# Iteration no. 162  max val fn diff is 0.005863632658925866
# Iteration no. 163  max val fn diff is 0.005680088342160161
# Iteration no. 164  max val fn diff is 0.005502292079277993
# Iteration no. 165  max val fn diff is 0.005330056500600477
# Iteration no. 166  max val fn diff is 0.005163207443565909
# Iteration no. 167  max val fn diff is 0.005001580767871161
# Iteration no. 168  max val fn diff is 0.004845011356295004
# Iteration no. 169  max val fn diff is 0.004693341987781707
# Iteration no. 170  max val fn diff is 0.004546420623537273
# Iteration no. 171  max val fn diff is 0.004404096263161961
# Iteration no. 172  max val fn diff is 0.004266225426512449
# Iteration no. 173  max val fn diff is 0.004132670989946519
# Iteration no. 174  max val fn diff is 0.004003296527059774
# Iteration no. 175  max val fn diff is 0.0038779686892311815
# Iteration no. 176  max val fn diff is 0.003756561724987506
# Iteration no. 177  max val fn diff is 0.0036390114339965862
# Iteration no. 178  max val fn diff is 0.003525163297446454
# Iteration no. 179  max val fn diff is 0.003414875025296027
# Iteration no. 180  max val fn diff is 0.0033080418459618954
# Iteration no. 181  max val fn diff is 0.0032045451795106317
# Iteration no. 182  max val fn diff is 0.003104289703276919
# Iteration no. 183  max val fn diff is 0.0030071652491372447
# Iteration no. 184  max val fn diff is 0.002913078924326129
# Iteration no. 185  max val fn diff is 0.002821935591633462
# Iteration no. 186  max val fn diff is 0.002733641989539848
# Iteration no. 187  max val fn diff is 0.0026481120089840715
# Iteration no. 188  max val fn diff is 0.002565255734552352
# Iteration no. 189  max val fn diff is 0.0024849914547253604
# Iteration no. 190  max val fn diff is 0.002407237968945708
# Iteration no. 191  max val fn diff is 0.002331916177407578
# Iteration no. 192  max val fn diff is 0.0022589517024727
# Iteration no. 193  max val fn diff is 0.002188269628394579
# Iteration no. 194  max val fn diff is 0.0021197987462109324
# Iteration no. 195  max val fn diff is 0.0020534699947809543
# Iteration no. 196  max val fn diff is 0.0019892151457234775
# Iteration no. 197  max val fn diff is 0.0019269699426303077
# Iteration no. 198  max val fn diff is 0.0018666718809789984
# Iteration no. 199  max val fn diff is 0.001808259962405856
# Iteration no. 200  max val fn diff is 0.0017516758761573215
# Iteration no. 201  max val fn diff is 0.0016968622433850555
# Iteration no. 202  max val fn diff is 0.0016437633399846163
# Iteration no. 203  max val fn diff is 0.0015923258592032141
# Iteration no. 204  max val fn diff is 0.001542497572408763
# Iteration no. 205  max val fn diff is 0.001494251180378825
# Iteration no. 206  max val fn diff is 0.0014475340181014928
# Iteration no. 207  max val fn diff is 0.0014022481168112222
# Iteration no. 208  max val fn diff is 0.0013583774348191469
# Iteration no. 209  max val fn diff is 0.0013158780659487945
# Iteration no. 210  max val fn diff is 0.001274707537522346
# Iteration no. 211  max val fn diff is 0.0012348243989279695
# Iteration no. 212  max val fn diff is 0.0011961884893665342
# Iteration no. 213  max val fn diff is 0.0011587609722809589
# Iteration no. 214  max val fn diff is 0.0011225041019287119
# Iteration no. 215  max val fn diff is 0.0010873811879399398
# Iteration no. 216  max val fn diff is 0.001053356728299093
# Iteration no. 217  max val fn diff is 0.0010203963874992894
# Iteration no. 218  max val fn diff is 0.000988466901102214
# Iteration no. 219  max val fn diff is 0.0009575360912208453
# Iteration no. 220  max val fn diff is 0.000927572825968781
# Iteration no. 221  max val fn diff is 0.0008985468960815979
# Iteration no. 222  max val fn diff is 0.0008704289844629898
# Iteration no. 223  max val fn diff is 0.0008431907018220386
# Iteration no. 224  max val fn diff is 0.000816804557530304
# Iteration no. 225  max val fn diff is 0.0007912439038868513
# Iteration no. 226  max val fn diff is 0.0007664829288884789
# Iteration no. 227  max val fn diff is 0.000742496647365698
# Iteration no. 228  max val fn diff is 0.000719260845222891
# Iteration no. 229  max val fn diff is 0.0006967520293024165
# Iteration no. 230  max val fn diff is 0.0006749474179699178
# Iteration no. 231  max val fn diff is 0.0006538249371565996
# Iteration no. 232  max val fn diff is 0.0006333632053276972
# Iteration no. 233  max val fn diff is 0.000613541528650785
# Iteration no. 234  max val fn diff is 0.0005943398984342707
# Iteration no. 235  max val fn diff is 0.0005757389590073103
# Iteration no. 236  max val fn diff is 0.0005577199546955569
# Iteration no. 237  max val fn diff is 0.0005402646955516843
# Iteration no. 238  max val fn diff is 0.0005233555508823429
# Iteration no. 239  max val fn diff is 0.000506975445802027
# Iteration no. 240  max val fn diff is 0.0004911078477327635
# Iteration no. 241  max val fn diff is 0.00047573674937595456
# Iteration no. 242  max val fn diff is 0.0004608466490481078
# Iteration no. 243  max val fn diff is 0.0004464225235274455
# Iteration no. 244  max val fn diff is 0.0004324497998844379
# Iteration no. 245  max val fn diff is 0.0004189143399422335
# Iteration no. 246  max val fn diff is 0.00040580243669552374
# Iteration no. 247  max val fn diff is 0.0003931008120225954
# Iteration no. 248  max val fn diff is 0.00038079661002043963
# Iteration no. 249  max val fn diff is 0.0003688773885102137
# Iteration no. 250  max val fn diff is 0.00035733110886937425
# Iteration no. 251  max val fn diff is 0.0003461461194298465
# Iteration no. 252  max val fn diff is 0.00033531113335527607
# Iteration no. 253  max val fn diff is 0.00032481520887728266
# Iteration no. 254  max val fn diff is 0.00031464773748624
# Iteration no. 255  max val fn diff is 0.0003047984366197909
# Iteration no. 256  max val fn diff is 0.00029525734221280686
# Iteration no. 257  max val fn diff is 0.0002860148004550922
# Iteration no. 258  max val fn diff is 0.00027706146119044206
# Iteration no. 259  max val fn diff is 0.0002683882722713804
# Iteration no. 260  max val fn diff is 0.00025998647194214186
# Iteration no. 261  max val fn diff is 0.000251847579107789
# Iteration no. 262  max val fn diff is 0.00024396338278620533
# Iteration no. 263  max val fn diff is 0.0002363259317910149
# Iteration no. 264  max val fn diff is 0.00022892752354053414
# Iteration no. 265  max val fn diff is 0.000221760692106443
# Iteration no. 266  max val fn diff is 0.0002148181976266983
# Iteration no. 267  max val fn diff is 0.00020809301906865585
# Iteration no. 268  max val fn diff is 0.00020157834966028076
# Iteration no. 269  max val fn diff is 0.0001952675925558367
# Iteration no. 270  max val fn diff is 0.00018915435581590145
# Iteration no. 271  max val fn diff is 0.00018323244702145303
# Iteration no. 272  max val fn diff is 0.000177495868541655
# Iteration no. 273  max val fn diff is 0.00017193881287980162
# Iteration no. 274  max val fn diff is 0.0001665556573264837
# Iteration no. 275  max val fn diff is 0.00016134095801234594
# Iteration no. 276  max val fn diff is 0.0001562894441136109
# Iteration no. 277  max val fn diff is 0.00015139601273972403
# Iteration no. 278  max val fn diff is 0.00014665572383876224
# Iteration no. 279  max val fn diff is 0.00014206379470138586
# Iteration no. 280  max val fn diff is 0.00013761559378266952
# Iteration no. 281  max val fn diff is 0.00013330663427879585
# Iteration no. 282  max val fn diff is 0.000129132567742829
# Iteration no. 283  max val fn diff is 0.00012508917834352928
# Iteration no. 284  max val fn diff is 0.00012117237773878742
# Iteration no. 285  max val fn diff is 0.00011737820150514722
# Iteration no. 286  max val fn diff is 0.00011370280655143006
# Iteration no. 287  max val fn diff is 0.00011014246907592451
# Iteration no. 288  max val fn diff is 0.00010669358213277746
# Iteration no. 289  max val fn diff is 0.00010335265228889057
# Iteration no. 290  max val fn diff is 0.00010011629623463136
# Iteration no. 291  max val fn diff is 9.698123763257627e-05

# %%
con
# Out:
# array([[ 0.61325388,  0.80662694,  1.        ,  0.74314795,  0.936521  ],
#        [ 1.07698575,  0.82013369,  1.01350675,  1.20687981,  0.95002776],
#        [ 1.0904925 ,  0.83364045,  1.02701351,  1.22038657,  0.96353451],
#        ...,
#        [28.93691571, 29.13028877, 28.87343672, 29.06680978, 28.80995772],
#        [28.95042247, 29.14379553, 28.88694347, 29.08031653, 28.82346448],
#        [28.96392922, 29.15730228, 28.90045023, 29.09382328, 28.83697123]])

# %%
      
# SIMULATE
if DoSimulate == 1:
    yindsim = np.zeros((Nsim,Tsim), dtype=int)
    aindsim = np.zeros((Nsim,Tsim), dtype=int)
    
    ## initial assets
    aindsim[:,0] = 0
    
    ## loop over time periods
    for it in range(0,Tsim):
        if Display >= 1 and (it+1)%100 == 0:
            print(' Simulating, time period ' + str(it+1))
        
        ### income realization: note we vectorize simulations at once because
        ### of matlab, in other languages we would loop over individuals
        yindsim[yrand[:,it]<=ycumdist[0],it] = 0
        for iy in range(1,ny):
            yindsim[np.logical_and(yrand[:,it]>ycumdist[iy-1], yrand[:,it]<=ycumdist[iy]),it] = iy
        
        ## asset choice
        if it < Tsim-1:
            for iy in range(0,ny):
                aindsim[yindsim[:,it]==iy,it+1] = savind[aindsim[yindsim[:,it]==iy,it],iy]

    ## assign actual asset and income values
    asim = agrid[aindsim]
    ysim = ygrid[yindsim]

# MAKE PLOTS
if MakePlots==1:
    
    ## consumption policy function
    plt.plot(agrid,con[:,0],'b-',label = 'Lowest income state')
    plt.plot(agrid,con[:,ny-1],'r-', label = 'Highest income state')
    plt.grid()
    plt.xlim((0,amax))
    ### plt.title('Consumption Policy Function')
    plt.title('Consumption')
    plt.legend()
    plt.show()

    ## savings policy function
    plt.plot(agrid,sav[:,0]-agrid[:,0],'b-')
    plt.plot(agrid,sav[:,ny-1]-agrid[:,0],'r-')
    plt.plot(agrid,np.zeros((na,1)),'k',linewidth=0.5)
    plt.grid()
    plt.xlim((0,amax))
    ### plt.title('Savings Policy Function (a''-a)')
    plt.title('Savings')
    plt.show()
    
    ## nice zoom
    xlimits = (0,1)
    xlimind = np.ones(na, dtype=bool)
    if np.min(agrid) < xlimits[0]:
        xlimind = np.logical_and(xlimind,(agrid[:,0]>=np.max(agrid[agrid<xlimits[0]])))
    elif np.min(agrid) > xlimits[1]:
        xlimind = 0
    if np.max(agrid) > xlimits[1]:
        xlimind = np.logical_and(xlimind,(agrid[:,0]<=np.min(agrid[agrid>xlimits[1]])))
    elif np.max(agrid) < xlimits[0]:
        xlimind = 0

    ## consumption policy function: zoomed in
    plt.plot(agrid[xlimind],con[xlimind,0],'b-o',linewidth=2)
    plt.plot(agrid[xlimind],con[xlimind,ny-1],'r-o',linewidth=2)
    plt.grid()
    plt.xlim(xlimits)
    plt.title('Consumption: Zoomed')
    plt.show()

    ## savings policy function: zoomed in
    plt.plot(agrid[xlimind],sav[xlimind,0]-agrid[xlimind,0],'b-o',linewidth=2)
    plt.plot(agrid[xlimind],sav[xlimind,ny-1]-agrid[xlimind,0],'r-o',linewidth=2)
    plt.plot(agrid,np.zeros((na,1)),'k',linewidth =0.5)
    plt.grid()
    plt.xlim(xlimits)
    plt.title('Savings: Zoomed (a\'-a)')
    plt.show()

    ## income distribution
    plt.hist(ysim[:,Tsim-1],len(ygrid),facecolor=(0,0.5,0.5),edgecolor='blue')
    plt.ylabel('')
    plt.title('Income distribution')
    plt.show()

    ## asset distribution
    plt.hist(asim[:,Tsim-1],40,facecolor=(.7,.7,.7),edgecolor='black')
    plt.ylabel('')
    plt.title('Asset distribution')
    plt.show()

    ## convergence check
    plt.plot(range(0,Tsim),np.mean(asim,0),'k-',linewidth=1.5)
    plt.xlabel('Time Period')
    plt.title('Mean Asset Convergence')
    plt.show()

    ## asset distribution statistics
    aysim = asim[:,Tsim-1]/np.mean(ysim[:,Tsim-1])
    print('Mean assets: ' + str(np.mean(aysim)))
    print('Fraction borrowing constrained: ' + str(np.sum(aysim==borrow_lim)/Nsim * 100) + '%')
    print('10th Percentile: ' + str(np.quantile(aysim,.1)))
    print('50th Percentile: ' + str(np.quantile(aysim,.5)))
    print('90th Percentile: ' + str(np.quantile(aysim,.9)))
    print('99th Percentile: ' + str(np.quantile(aysim,.99)))
# Out:
#  Simulating, time period 100
#  Simulating, time period 200
#  Simulating, time period 300
#  Simulating, time period 400
#  Simulating, time period 500
#  Simulating, time period 600
#  Simulating, time period 700
#  Simulating, time period 800
#  Simulating, time period 900
#  Simulating, time period 1000
#  Simulating, time period 1100
#  Simulating, time period 1200
#  Simulating, time period 1300
#  Simulating, time period 1400
#  Simulating, time period 1500
#  Simulating, time period 1600
#  Simulating, time period 1700
#  Simulating, time period 1800
#  Simulating, time period 1900
#  Simulating, time period 2000
#  Simulating, time period 2100
#  Simulating, time period 2200
#  Simulating, time period 2300
#  Simulating, time period 2400
#  Simulating, time period 2500
# Mean assets: 3.8398738192762463
# Fraction borrowing constrained: 1.396%
# 10th Percentile: 0.9005860613957777
# 50th Percentile: 4.052637276281
# 90th Percentile: 6.754395460468332
# 99th Percentile: 7.654981521864109
